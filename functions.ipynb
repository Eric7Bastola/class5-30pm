# %%
#def <function_name>(): #defining
 #   <operations>
    
#<function_name>()      #calling

# %%
def hello():

    print("oiiiii")
hello()
# Out:
# oiiiii

# %%
def area():
    global v,B
    l=int(input("ENTER THE VALUE OF A = "))
    B=int(input("enter the value of b = "))
    h=int(input("Enter the value of h = "))
    v=l*B*h
    print("The volume of the cuboid is",v,"metre square")
area()
print(B)
print(v)
# Out:
# ENTER THE VALUE OF A = 10
# enter the value of b = 20
# Enter the value of h = 30
# The volume of the cuboid is 6000 metre square
# 20
# 6000

# %%
def area(l,B,h):

    
    v=l*B*h
    print("The volume of the cuboid is",v,"metre square")
l=int(input("ENTER THE VALUE OF A = "))
B=int(input("enter the value of b = "))
h=int(input("Enter the value of h = "))
area(l,B,h)
print(B)
# Out:
# ENTER THE VALUE OF A = 20
# enter the value of b = 30
# Enter the value of h = 40
# The volume of the cuboid is 24000 metre square
# 30

# %%
#arguments and return type
def oi(B):
    print(B)
oi("HELLO")
# Out:
# HELLO

# %%
def eric(p,q):
    d=(1/2)*(p*q)
    print(d)
a=int(input("Enter the value of a = "))
b=int(input("Enter the value of b = "))
eric(a,b)
# Out:
# Enter the value of a = 20
# Enter the value of b = 10
# 100.0

# %%
def area(l,b):
    area=2*(l*b+b*h+l*h)
    print("The surface area of the item is",area,"metre square")
def volume(l,b,h):
    v=l*b*h
    print("The volume of the item is",v,"metre cube")
l=float(input("Enter the length of the item = "))
b=float(input("Enter the breath of the item = "))
h=float(input("Enter the height of the item = "))
area(l,b)
volume(l,b,h)
# Out:
# Enter the length of the item = 20
# Enter the breath of the item = 30
# Enter the height of the item = 40
# The surface area of the item is 5200.0 metre square
# The volume of the item is 24000.0 metre cube

# %%
def oi(l):
    x= f"Hello world, My name is {l['X']}. I am {l['Y']} years old. I live in {l['a']}."
    print(x)
name=input("Enter your name = ")
age=int(input("Enter your age = "))
address=input("Enter your addresss = ")
l={'X':name,'Y':age,'a':address}
oi(l)
# Out:
# Enter your name = ERIC BASTOLA
# Enter your age = 16
# Enter your addresss = SANTINAGR
# Hello world, My name is ERIC BASTOLA. I am 16 years old. I live in SANTINAGR.

# %%
a= int(input("Enter a = "))
b= int(input("Enter b = "))
o= input("Enter + or - or / or * = ")
def add(a,b):
    print(a+b)
def sub(a,b):
    print(a-b)
def mul(a,b):
    print(a*b)
def div(a,b):
    print(a/b)
def calu(a,b,o):
    if o=="+":
        add(a,b)
    elif o=="-":
        sub(a,b)
    elif o=="*":
        mul(a,b)
    elif o=="/" and b!=0:
        div(a,b)
    elif o=="/" and b==0:
        print("The operation cannot be perfomed")
    else:
        print("Talai input garna aaudeina bhaiii")
calu(a,b,o)
# Out:
# Enter a = 3
# Enter b = 4
# Enter + or - or / or * = r
# Talai input garna aaudeina bhaiii

# %%
#return type functions
def hello(h):
    print(h)
h=input("Enter a string = ")
hello(h)
# Out:
# Enter a string = aayusha
# aayusha

# %%
def area():
    a=15
    b=60
    x=a*b
    return x
y=area()
def volume():
    v=y*10
    print("The volume of the mass is",v)
volume()
# Out:
# The volume of the mass is 9000

# %%
def cal(l,b,h):
    area=l*b
    v= area*h
    return area,v
l = 15
b = 156
h = 3
x = cal(l,b,h)

print(x)
d=x[0]/2340
print(d)
e=x[1]*2
print(e)
# Out:
# (2340, 7020)
# 1.0
# 14040

# %%
def cal(l,b,h):
    area=l*b
    v= area*h
    return area,v
l = 15
b = 156
h = 3
x = cal(l,b,h)
a,vo=x
print("area is",a)
print("volume is ",vo)
# Out:
# area is 2340
# volume is  7020

# %%
a=int(input("Enter the value of a= "))
b=int(input("Enter the value of b= "))
o=input("Enter an operation i.e + or - or * or /")
def add(a,b):
    return a+b
def sub(a,b):
    return a-b
def mul(a,b):
    return a*b
def div(a,b):
    return a/b
def cal():
    if o=="+":
        print(add(a,b))
    elif o=="-":
        print(sub(a,b))
    elif o=="*":
        print(mul(a,b))
    elif o=="/" and b==0:
        print("Operation cannot be performed")
    elif o=="/" and b!=0:
        print(div(a,b))
    else:
        print("Talai value hanna aaudeina bhaiiii!!!")
cal()
# Out:
# Enter the value of a= 10
# Enter the value of b= 5
# Enter an operation i.e + or - or * or //
# 2.0

# %%
# recursive function
def mero():
    print("eric")
    mero()
mero()
# Out:
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# eric
# ...

# %%
def hello():
    print("hello world")
    x=input("Type stop to stop= ").upper()
    if x!="stop".upper():
        hello()
hello()
# Out:
# hello world
# Type stop to stop= e
# hello world
# Type stop to stop= e
# hello world
# Type stop to stop= r
# hello world
# Type stop to stop= stop

# %%
def si():
    p=int(input("enter principle = "))
    r=int(input("enter rate = "))
    t=int(input("enter time = "))
    i=p*t*r/100
    print("Simple interest is= ",i)
    
    s=input("Enter more for further calculations= ").upper()
    if s=="more".upper():
        si()
si()
# Out:
# enter principle = 100000
# enter rate = 12
# enter time = 4
# Simple interest is=  48000.0
# Enter more for further calculations= MORE
# enter principle = 30000
# enter rate = 12
# enter time = 3
# Simple interest is=  10800.0
# Enter more for further calculations= more
# enter principle = 3000000
# enter rate = 4
# enter time = 4
# Simple interest is=  480000.0
# Enter more for further calculations= no
